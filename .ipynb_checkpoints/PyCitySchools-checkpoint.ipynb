# %%
import matplotlib.pyplot as plt
import os
import csv
import pandas as pd
import numpy as np
from collections import Counter

# %%
os.path.abspath('.')
os.chdir('/Users/philipharmon/Desktop/unc-data-homework/pandas-challenge')
os.getcwd()
print("The current working directory is", os.getcwd())
# Out:
# The current working directory is /Users/philipharmon/Desktop/unc-data-homework/pandas-challenge

# %%
# File to Load (Remember to Change These)
school_data_to_load = '/Users/philipharmon/Desktop/unc-data-homework/pandas-challenge/schools_complete.csv'
student_data_to_load = '/Users/philipharmon/Desktop/unc-data-homework/pandas-challenge/students_complete.csv'

# %%
# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
# Combine the data into a single dataset
school_data_complete_df = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete_df.head(10)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
# 7           7       Nicole Baker      F  12th  Huang High School
# 8           8       Michael Roth      M  10th  Huang High School
# 9           9     Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635
# 7             96          69          0  District  2917  1910635
# 8             95          87          0  District  2917  1910635
# 9             96          84          0  District  2917  1910635

# %%
# Get a lay of the land
# returns a table of summary statistics on numeric columns in a dataframe
school_data_complete_df.describe()

# This gives a good reference to compare to results from other code
# Out:
#          Student ID  reading_score    math_score     School ID          size  \
# count  39170.000000    39170.00000  39170.000000  39170.000000  39170.000000
# mean   19584.500000       81.87784     78.985371      6.978172   3332.957110
# std    11307.549359       10.23958     12.309968      4.444329   1323.914069
# min        0.000000       63.00000     55.000000      0.000000    427.000000
# 25%     9792.250000       73.00000     69.000000      3.000000   1858.000000
# 50%    19584.500000       82.00000     79.000000      7.000000   2949.000000
# 75%    29376.750000       91.00000     89.000000     11.000000   4635.000000
# max    39169.000000       99.00000     99.000000     14.000000   4976.000000
#
#              budget
# count  3.917000e+04
# mean   2.117241e+06
# std    8.749987e+05
# min    2.480870e+05
# 25%    1.081356e+06
# 50%    1.910635e+06
# 75%    3.022020e+06
# max    3.124928e+06

# %%
# Get a lay of the land: reading scores
school_data_complete_df["reading_score"].describe()
# Out:
# count    39170.00000
# mean        81.87784
# std         10.23958
# min         63.00000
# 25%         73.00000
# 50%         82.00000
# 75%         91.00000
# max         99.00000
# Name: reading_score, dtype: float64

# %%
# Get a lay of the land: math scores
school_data_complete_df["math_score"].describe()
# Out:
# count    39170.000000
# mean        78.985371
# std         12.309968
# min         55.000000
# 25%         69.000000
# 50%         79.000000
# 75%         89.000000
# max         99.000000
# Name: math_score, dtype: float64

# %%
# Get a lay of the land: school size
school_data_complete_df["size"].describe()
# Out:
# count    39170.000000
# mean      3332.957110
# std       1323.914069
# min        427.000000
# 25%       1858.000000
# 50%       2949.000000
# 75%       4635.000000
# max       4976.000000
# Name: size, dtype: float64

# %%
# Get a lay of the land: budget
school_data_complete_df["budget"].describe()
# Out:
# count    3.917000e+04
# mean     2.117241e+06
# std      8.749987e+05
# min      2.480870e+05
# 25%      1.081356e+06
# 50%      1.910635e+06
# 75%      3.022020e+06
# max      3.124928e+06
# Name: budget, dtype: float64

# %%
# Get a lay of the land: number of rows and columns
school_data_complete_df.shape
# Out:
# (39170, 11)

# %%
# CALCULATE THE NUMBER OF SCHOOLS

# %%
# Calculate the number of schools
number_of_schools_df = school_data_complete_df["school_name"].nunique()
number_of_schools_df
# Out:
# 15

# %%
# CALCULATE THE TOTAL NUMBER OF STUDENTS

# %%
# Calculate the total number of students
number_of_students_df = school_data_complete_df["student_name"].count()
number_of_students_df
# Out:
# 39170

# %%
# CALCULATE THE AVERAGE MATH SCORE

# %%
# Calculate the average math score
average_math_score_df = school_data_complete_df["math_score"].mean()
average_math_score_df
# Out:
# 78.98537145774827

# %%
# CALCULATE THE AVERAGE READING SCORES

# %%
# calculate the average reading scores
average_reading_score_df = school_data_complete_df["reading_score"].mean()
average_reading_score_df
# Out:
# 81.87784018381414

# %%
# MAKE A NEW COLUMN TO GET THE OVERALL AVERAGE SCORE OF READING AND MATH

# %%
overall_passing_df = school_data_complete_df.loc[:, ["reading_score", "math_score"]].mean()
overall_passing_df
# Out:
# reading_score    81.877840
# math_score       78.985371
# dtype: float64

# %%
# Find out how many students are passing reading
passing_reading_bins = [0, 69, 100]
passing_reading_labels = ["fail", "pass"]
pd.cut(school_data_complete_df["reading_score"], passing_reading_bins, labels=passing_reading_labels)
school_data_complete_df["pass reading"] = pd.cut(school_data_complete_df["reading_score"], passing_reading_bins, labels=passing_reading_labels)
school_data_complete_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
#       pass reading
# 0             fail
# 1             pass
# 2             pass
# 3             fail
# 4             pass
# ...            ...
# 39165         pass
# 39166         pass
# 39167         pass
# 39168         pass
# 39169         pass
#
# [39170 rows x 12 columns]

# %%
# Get a count of how many students are passing and failing
print(school_data_complete_df["pass reading"].value_counts())
# Out:
# pass    33610
# fail     5560
# Name: pass reading, dtype: int64

# %%
# Find out how many students are passing reading
passing_math_bins = [0, 69, 100]
passing_math_labels = ["fail", "pass"]
pd.cut(school_data_complete_df["math_score"], passing_math_bins, labels=passing_math_labels)
school_data_complete_df["pass math"] = pd.cut(school_data_complete_df["math_score"], passing_math_bins, labels=passing_reading_labels)
school_data_complete_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
#       pass reading pass math
# 0             fail      pass
# 1             pass      fail
# 2             pass      fail
# 3             fail      fail
# 4             pass      pass
# ...            ...       ...
# 39165         pass      pass
# 39166         pass      pass
# 39167         pass      pass
# 39168         pass      pass
# 39169         pass      pass
#
# [39170 rows x 13 columns]

# %%
# Get a count of how many students are passing and failing
print(school_data_complete_df["pass math"].value_counts())
# Out:
# pass    29370
# fail     9800
# Name: pass math, dtype: int64

# %%
left = pd.DataFrame(school_data_complete_df["pass reading"])
right = pd.DataFrame(school_data_complete_df["pass math"])
left.join(right)
school_data_complete_df.head(15)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# 13          13       William Long      M   9th  Huang High School
# 14          14       Tammy Hebert      F  10th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget  \
# 0              66          79          0  District  2917  1910635
# 1              94          61          0  District  2917  1910635
# 2              90          60          0  District  2917  1910635
# 3              67          58          0  District  2917  1910635
# 4              97          84          0  District  2917  1910635
# 5              94          94          0  District  2917  1910635
# 6              82          80          0  District  2917  1910635
# 7              96          69          0  District  2917  1910635
# 8              95          87          0  District  2917  1910635
# 9              96          84          0  District  2917  1910635
# 10             90          70          0  District  2917  1910635
# 11             78          77          0  District  2917  1910635
# 12             64          79          0  District  2917  1910635
# 13             71          79          0  District  2917  1910635
# 14             85          67          0  District  2917  1910635
#
#    pass reading pass math
# 0          fail      pass
# 1          pass      fail
# 2          pass      fail
# 3          fail      fail
# 4          pass      pass
# 5          pass      pass
# 6          pass      pass
# 7          pass      fail
# 8          pass      pass
# 9          pass      pass
# 10         pass      pass
# 11         pass      pass
# 12         fail      pass
# 13         pass      pass
# 14         pass      fail

# %%
# MAKE A NEW COLUMN TO GET THE OVERALL AVERAGE SCORE OF READING AND MATH
pd.concat([school_data_complete_df["pass reading"], school_data_complete_df["pass math"]], axis=1)
school_data_complete_df.head(15)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# 13          13       William Long      M   9th  Huang High School
# 14          14       Tammy Hebert      F  10th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget  \
# 0              66          79          0  District  2917  1910635
# 1              94          61          0  District  2917  1910635
# 2              90          60          0  District  2917  1910635
# 3              67          58          0  District  2917  1910635
# 4              97          84          0  District  2917  1910635
# 5              94          94          0  District  2917  1910635
# 6              82          80          0  District  2917  1910635
# 7              96          69          0  District  2917  1910635
# 8              95          87          0  District  2917  1910635
# 9              96          84          0  District  2917  1910635
# 10             90          70          0  District  2917  1910635
# 11             78          77          0  District  2917  1910635
# 12             64          79          0  District  2917  1910635
# 13             71          79          0  District  2917  1910635
# 14             85          67          0  District  2917  1910635
#
#    pass reading pass math
# 0          fail      pass
# 1          pass      fail
# 2          pass      fail
# 3          fail      fail
# 4          pass      pass
# 5          pass      pass
# 6          pass      pass
# 7          pass      fail
# 8          pass      pass
# 9          pass      pass
# 10         pass      pass
# 11         pass      pass
# 12         fail      pass
# 13         pass      pass
# 14         pass      fail

# %%
# CALCULATE THE OVERALL PASSING RATE (OVERALL AVERAGE SCORE): (AVG.MATH SCORE + AVG.READING SCORE)/2

# %%
overall_passing_rate_df = ((average_math_score_df) + (average_reading_score_df)) / 2
overall_passing_rate_df
# Out:
# 80.43160582078121

# %%
# CALCULATE THE PERCENTAGE OF STUDENTS WITH A PASSING MATH SCORE (70 OR GREATER)

# %%
students_passing_math_df = school_data_complete_df["pass math"].where(school_data_complete_df["pass math"] >= 70)
students_passing_math_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-9b3e8409a193> in <module>
# ----> 1 students_passing_math_df = school_data_complete_df["pass math"].where(school_data_complete_df["pass math"] >= 70)
#       2 students_passing_math_df
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1145             # Dispatch to Categorical implementation; pd.CategoricalIndex
#    1146             # behavior is non-canonical GH#19513
# -> 1147             res_values = dispatch_to_index_op(op, self, other, pd.Categorical)
#    1148             return self._constructor(res_values, index=self.index, name=res_name)
#    1149
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/ops/__init__.py in dispatch_to_index_op(op, left, right, index_class)
#     628         left_idx = left_idx._shallow_copy(freq=None)
#     629     try:
# --> 630         result = op(left_idx, right)
#     631     except NullFrequencyError:
#     632         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/arrays/categorical.py in f(self, other)
#     140                         "scalar, which is not a category."
#     141                     )
# --> 142                     raise TypeError(msg.format(op=op))
#     143         else:
#     144
#
# TypeError: Cannot compare a Categorical for op __ge__ with a scalar, which is not a category.

# %%
# CALCULATE THE PERCENTAGE OF STUDENTS WITH A PASSING READING SCORE (70 OR GREATER)

# %%
# Create a dataframe to hold the above results

# %%
# Give the displayed data cleaner formatting
